# %% [markdown]
# # CIFAR-10 Advanced Functional Architectures
#
# This notebook applies graph-based network design to CIFAR-10. It includes a functional CNN baseline, parallel branches, skip connections, combined branch-and-skip designs, Inception-style modules, residual networks, and residual networks with parallel branches.

# %% [markdown]
# ## Setup and CIFAR-10 Data

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras import Model, Input
from tensorflow.keras.layers import *
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.20.0

# %%
(x_train, y_train_raw), (x_test, y_test_raw) = tf.keras.datasets.cifar10.load_data()
# Convert from uint8 to float and scale in [0,1] range
x_train = np.float32(x_train/255.0)
x_test = np.float32(x_test/255.0)
label = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']

# One-hot encode the labels
y_train = to_categorical(y_train_raw.flatten(), 10)
y_test  = to_categorical(y_test_raw.flatten(), 10)

# %%
def plot_results(all_history):
  loss, val_loss, accuracy, val_accuracy = [], [], [], []
  for history in all_history:
    loss += history.history['loss']
    val_loss += history.history['val_loss']
    accuracy += history.history['accuracy']
    val_accuracy += history.history['val_accuracy']

  fig, ax = plt.subplots()
  ax.plot(accuracy,label = 'train')
  ax.plot(val_accuracy,label = 'test')
  ax.set_title('Accuracy')
  ax.legend(loc='lower right')
  fig, ax = plt.subplots()
  ax.plot(loss,label = 'train')
  ax.plot(val_loss,label = 'test')
  ax.set_title('Loss')
  ax.legend(loc='upper right')

# %% [markdown]
# ## Functional CNN Baseline with Batch Normalization and Dropout

# %%
def cnn_model_api(input_shape=(32, 32, 3), num_classes=10):
    inputs = Input(shape=input_shape)

    # Block 1
    net = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    net = BatchNormalization()(net)
    net = Conv2D(32, (3, 3), activation='relu', padding='same')(net)
    net = BatchNormalization()(net)
    net = MaxPooling2D(pool_size=(2, 2))(net)
    net = Dropout(0.25)(net)

    # Block 2
    net = Conv2D(64, (3, 3), activation='relu', padding='same')(net)
    net = BatchNormalization()(net)
    net = Conv2D(64, (3, 3), activation='relu', padding='same')(net)
    net = BatchNormalization()(net)
    net = MaxPooling2D(pool_size=(2, 2))(net)
    net = Dropout(0.25)(net)

    # Block 3
    net = Conv2D(128, (3, 3), activation='relu', padding='same')(net)
    net = BatchNormalization()(net)
    net = Conv2D(128, (3, 3), activation='relu', padding='same')(net)
    net = BatchNormalization()(net)
    net = MaxPooling2D(pool_size=(2, 2))(net)
    net = Dropout(0.4)(net)

    # Fully connected layers
    net = Flatten()(net)
    net = Dense(256, activation='relu')(net)
    net = BatchNormalization()(net)
    net = Dropout(0.5)(net)

    outputs = Dense(num_classes, activation='softmax')(net)

    # Define model
    model = Model(inputs=inputs, outputs=outputs, name='cifar10_functional_model')
    return model

# %%
cnn = cnn_model_api()
cnn.summary()
# Out:
# Model: "cifar10_functional_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_20 (InputLayer)     │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_205 (Conv2D)             │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_117         │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_206 (Conv2D)             │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_118         │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_46 (MaxPooling2D) │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_49 (Dropout)            │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_207 (Conv2D)             │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_119         │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_208 (Conv2D)             │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_120         │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_47 (MaxPooling2D) │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_50 (Dropout)            │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_209 (Conv2D)             │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_121         │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_210 (Conv2D)             │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_122         │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_48 (MaxPooling2D) │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_51 (Dropout)            │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_12 (Flatten)            │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_123         │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_52 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 816,938 (3.12 MB)
#  Trainable params: 815,530 (3.11 MB)
#  Non-trainable params: 1,408 (5.50 KB)

# %%
plot_model(cnn, to_file='model_plot.png', show_shapes=True, show_layer_names=True, dpi=64)

# %%
cnn.compile(loss="categorical_crossentropy", metrics=["accuracy"])
history = cnn.fit(
    x_train, y_train,
    epochs =  10,
    batch_size=256,
    verbose = 1,
    validation_data=(x_test, y_test),
)

print('Final accuracy on training set: {:.4f}'.format(history.history['accuracy'][-1]))
print('Final accuracy on test set: {:.4f}'.format(np.mean(history.history['val_accuracy'][-1])))
print('Mean accuracy in last 5 epochs: {:.4f}'.format(np.mean(history.history['val_accuracy'][-5:])))
# Out:
# Epoch 1/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 19s 51ms/step - accuracy: 0.4259 - loss: 1.7694 - val_accuracy: 0.1087 - val_loss: 3.8974
# Epoch 2/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6240 - loss: 1.0706 - val_accuracy: 0.3019 - val_loss: 2.3366
# Epoch 3/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7017 - loss: 0.8489 - val_accuracy: 0.6516 - val_loss: 0.9905
# Epoch 4/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7426 - loss: 0.7329 - val_accuracy: 0.6999 - val_loss: 0.8909
# Epoch 5/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7704 - loss: 0.6583 - val_accuracy: 0.7551 - val_loss: 0.7264
# Epoch 6/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7913 - loss: 0.5978 - val_accuracy: 0.7433 - val_loss: 0.7761
# Epoch 7/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8088 - loss: 0.5572 - val_accuracy: 0.7286 - val_loss: 0.8127
# Epoch 8/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8196 - loss: 0.5162 - val_accuracy: 0.7956 - val_loss: 0.6119
# Epoch 9/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8318 - loss: 0.4882 - val_accuracy: 0.7964 - val_loss: 0.6032
# Epoch 10/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8406 - loss: 0.4571 - val_accuracy: 0.8071 - val_loss: 0.5721
# Final accuracy on training set: 0.8406
# Final accuracy on test set: 0.8071
# Mean accuracy in last 5 epochs: 0.7742

# %% [markdown]
# ## Parallel-Branch CNN

# %%
def cnn_model_api(input_shape=(28,28,1)):
  inputs = Input(shape=input_shape)
  branch1 = Conv2D(32, kernel_size=(3, 3),activation='relu', padding='same')(inputs)
  branch1 = Conv2D(32, kernel_size=(3, 3),activation='relu', padding='same')(branch1)
  branch2 = Conv2D(32, kernel_size=(5, 5),activation='relu', padding='same')(inputs)
  branch3 = Conv2D(32, kernel_size=(1, 1),activation='relu', padding='same')(inputs)
  branch3 = Conv2D(32, kernel_size=(5, 5),activation='relu', padding='same')(branch3)
  concatanated = Concatenate()([branch1,branch2,branch3])
  net = MaxPooling2D(pool_size=(2, 2))(concatanated)
  net = Dropout(0.2)(net)
  net = Conv2D(64, kernel_size=(3, 3),activation='relu', padding='same')(net)
  net = Conv2D(64, kernel_size=(3, 3),activation='relu', padding='same')(net)
  net = MaxPooling2D(pool_size=(2, 2))(net)
  net = Dropout(0.2)(net)
  net = Conv2D(128, kernel_size=(3, 3),activation='relu', padding='same')(net)
  net = Conv2D(128, kernel_size=(3, 3),activation='relu', padding='same')(net)
  net = MaxPooling2D(pool_size=(2, 2))(net)
  net = Dropout(0.2)(net)
  net = Flatten()(net)
  net = Dense(128, activation='relu')(net)
  net = Dropout(0.2)(net)
  outputs = Dense(10, activation='softmax')(net)
  model = Model(inputs=inputs, outputs=outputs, name='classification_model')
  return model

# %%
cnn = cnn_model_api(input_shape=x_train.shape[1:])
# plot_model(cnn, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
# !pip install graphviz
# Out:
# Requirement already satisfied: graphviz in /usr/local/lib/python3.13/dist-packages (0.21)

# %%
cnn.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss="categorical_crossentropy", metrics=["accuracy"])
history = cnn.fit(
    x_train, y_train,
    epochs =  40,
    batch_size=100,
    verbose = 2,
    validation_data=(x_test, y_test),
)

print('Final accuracy on training set: {:.4f}'.format(history.history['accuracy'][-1]))
print('Final accuracy on test set: {:.4f}'.format(history.history['val_accuracy'][-1]))
print('Mean accuracy in last 5 epochs: {:.4f}'.format(np.mean(history.history['val_accuracy'][-5:])))
# Out:
# Epoch 1/40
# 500/500 - 12s - 23ms/step - accuracy: 0.3863 - loss: 1.6571 - val_accuracy: 0.5309 - val_loss: 1.2828
# Epoch 2/40
# 500/500 - 3s - 6ms/step - accuracy: 0.5746 - loss: 1.1836 - val_accuracy: 0.6537 - val_loss: 0.9780
# Epoch 3/40
# 500/500 - 3s - 6ms/step - accuracy: 0.6606 - loss: 0.9616 - val_accuracy: 0.7028 - val_loss: 0.8468
# Epoch 4/40
# 500/500 - 3s - 6ms/step - accuracy: 0.7065 - loss: 0.8374 - val_accuracy: 0.7319 - val_loss: 0.7651
# Epoch 5/40
# 500/500 - 3s - 6ms/step - accuracy: 0.7348 - loss: 0.7522 - val_accuracy: 0.7521 - val_loss: 0.7309
# Epoch 6/40
# 500/500 - 3s - 6ms/step - accuracy: 0.7641 - loss: 0.6801 - val_accuracy: 0.7584 - val_loss: 0.6970
# Epoch 7/40
# 500/500 - 3s - 6ms/step - accuracy: 0.7837 - loss: 0.6217 - val_accuracy: 0.7747 - val_loss: 0.6713
# Epoch 8/40
# 500/500 - 3s - 6ms/step - accuracy: 0.7999 - loss: 0.5749 - val_accuracy: 0.7947 - val_loss: 0.6162
# Epoch 9/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8139 - loss: 0.5296 - val_accuracy: 0.7912 - val_loss: 0.6270
# Epoch 10/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8245 - loss: 0.5002 - val_accuracy: 0.8008 - val_loss: 0.5932
# Epoch 11/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8329 - loss: 0.4725 - val_accuracy: 0.8079 - val_loss: 0.5958
# Epoch 12/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8425 - loss: 0.4464 - val_accuracy: 0.7933 - val_loss: 0.6215
# Epoch 13/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8489 - loss: 0.4272 - val_accuracy: 0.8000 - val_loss: 0.6344
# Epoch 14/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8552 - loss: 0.4089 - val_accuracy: 0.8005 - val_loss: 0.6050
# Epoch 15/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8648 - loss: 0.3822 - val_accuracy: 0.8074 - val_loss: 0.6117
# Epoch 16/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8677 - loss: 0.3720 - val_accuracy: 0.8086 - val_loss: 0.5953
# Epoch 17/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8739 - loss: 0.3557 - val_accuracy: 0.8077 - val_loss: 0.6212
# Epoch 18/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8759 - loss: 0.3481 - val_accuracy: 0.8161 - val_loss: 0.5966
# Epoch 19/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8809 - loss: 0.3334 - val_accuracy: 0.8148 - val_loss: 0.6375
# Epoch 20/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8854 - loss: 0.3220 - val_accuracy: 0.8160 - val_loss: 0.6189
# Epoch 21/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8912 - loss: 0.3108 - val_accuracy: 0.8175 - val_loss: 0.6338
# Epoch 22/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8935 - loss: 0.3001 - val_accuracy: 0.8172 - val_loss: 0.6412
# Epoch 23/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8937 - loss: 0.2929 - val_accuracy: 0.8178 - val_loss: 0.6343
# Epoch 24/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8969 - loss: 0.2926 - val_accuracy: 0.8151 - val_loss: 0.6334
# Epoch 25/40
# 500/500 - 3s - 6ms/step - accuracy: 0.9002 - loss: 0.2776 - val_accuracy: 0.8191 - val_loss: 0.6367
# Epoch 26/40
# 500/500 - 3s - 6ms/step - accuracy: 0.9016 - loss: 0.2787 - val_accuracy: 0.8209 - val_loss: 0.6589
# Epoch 27/40
# 500/500 - 3s - 6ms/step - accuracy: 0.9060 - loss: 0.2653 - val_accuracy: 0.8251 - val_loss: 0.6370
# Epoch 28/40
# 500/500 - 3s - 6ms/step - accuracy: 0.9066 - loss: 0.2649 - val_accuracy: 0.8212 - val_loss: 0.6401
# Epoch 29/40
# 500/500 - 3s - 6ms/step - accuracy: 0.9086 - loss: 0.2542 - val_accuracy: 0.8246 - val_loss: 0.6379
# Epoch 30/40
# 500/500 - 3s - 6ms/step - accuracy: 0.9103 - loss: 0.2506 - val_accuracy: 0.8234 - val_loss: 0.6457
# Epoch 31/40
# 500/500 - 3s - 6ms/step - accuracy: 0.9135 - loss: 0.2483 - val_accuracy: 0.8259 - val_loss: 0.6478
# Epoch 32/40
# 500/500 - 3s - 6ms/step - accuracy: 0.9126 - loss: 0.2459 - val_accuracy: 0.8239 - val_loss: 0.6493
# Epoch 33/40
# 500/500 - 3s - 6ms/step - accuracy: 0.9139 - loss: 0.2393 - val_accuracy: 0.8255 - val_loss: 0.6273
# Epoch 34/40
# 500/500 - 3s - 6ms/step - accuracy: 0.9175 - loss: 0.2339 - val_accuracy: 0.8203 - val_loss: 0.6777
# Epoch 35/40
# 500/500 - 3s - 6ms/step - accuracy: 0.9207 - loss: 0.2293 - val_accuracy: 0.8191 - val_loss: 0.6839
# Epoch 36/40
# 500/500 - 3s - 6ms/step - accuracy: 0.9207 - loss: 0.2263 - val_accuracy: 0.8197 - val_loss: 0.6856
# Epoch 37/40
# 500/500 - 3s - 6ms/step - accuracy: 0.9192 - loss: 0.2267 - val_accuracy: 0.8228 - val_loss: 0.6334
# Epoch 38/40
# 500/500 - 3s - 6ms/step - accuracy: 0.9215 - loss: 0.2219 - val_accuracy: 0.8217 - val_loss: 0.7235
# Epoch 39/40
# 500/500 - 3s - 6ms/step - accuracy: 0.9255 - loss: 0.2151 - val_accuracy: 0.8275 - val_loss: 0.6888
# Epoch 40/40
# 500/500 - 3s - 6ms/step - accuracy: 0.9232 - loss: 0.2173 - val_accuracy: 0.8265 - val_loss: 0.6825
# Final accuracy on training set: 0.9232
# Final accuracy on test set: 0.8265
# Mean accuracy in last 5 epochs: 0.8236

# %% [markdown]
# ## Skip-Connection CNN

# %%
def cnn_model_api(input_shape=(28,28,1)):
  inputs = Input(shape=input_shape)
  net = Conv2D(32, kernel_size=(3, 3),activation='relu', padding='same')(inputs)
  net = Conv2D(32, kernel_size=(3, 3),activation='relu', padding='same')(net)
  skip = MaxPooling2D(pool_size=(2, 2))(net)
  net = Conv2D(32, kernel_size=(3, 3),activation='relu', padding='same')(skip)
  net = Conv2D(32, kernel_size=(3, 3),activation='relu', padding='same')(net)
  added = Add()([net,skip])
  net = MaxPooling2D(pool_size=(2, 2))(added)
  net = Dropout(0.2)(net)
  net = Conv2D(128, kernel_size=(3, 3),activation='relu', padding='same')(net)
  net = Conv2D(128, kernel_size=(3, 3),activation='relu', padding='same')(net)
  net = MaxPooling2D(pool_size=(2, 2))(net)
  net = Dropout(0.2)(net)
  net = Flatten()(net)
  net = Dense(128, activation='relu')(net)
  net = Dropout(0.2)(net)
  outputs = Dense(10, activation='softmax')(net)
  model = Model(inputs=inputs, outputs=outputs, name='classification_model')
  return model

# %%
cnn = cnn_model_api(input_shape=x_train.shape[1:])
# plot_model(cnn, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
cnn.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss="categorical_crossentropy", metrics=["accuracy"])
history = cnn.fit(
    x_train, y_train,
    epochs =  40,
    batch_size=100,
    verbose = 2,
    validation_data=(x_test, y_test),
)

print('Final accuracy on training set: {:.4f}'.format(history.history['accuracy'][-1]))
print('Final accuracy on test set: {:.4f}'.format(history.history['val_accuracy'][-1]))
print('Mean accuracy in last 5 epochs: {:.4f}'.format(np.mean(history.history['val_accuracy'][-5:])))
# Out:
# Epoch 1/40
# 500/500 - 9s - 18ms/step - accuracy: 0.3967 - loss: 1.6307 - val_accuracy: 0.5644 - val_loss: 1.1905
# Epoch 2/40
# 500/500 - 2s - 4ms/step - accuracy: 0.5847 - loss: 1.1601 - val_accuracy: 0.6370 - val_loss: 1.0412
# Epoch 3/40
# 500/500 - 2s - 4ms/step - accuracy: 0.6609 - loss: 0.9613 - val_accuracy: 0.7097 - val_loss: 0.8343
# Epoch 4/40
# 500/500 - 2s - 4ms/step - accuracy: 0.7065 - loss: 0.8405 - val_accuracy: 0.7318 - val_loss: 0.7574
# Epoch 5/40
# 500/500 - 2s - 4ms/step - accuracy: 0.7352 - loss: 0.7601 - val_accuracy: 0.7564 - val_loss: 0.7015
# Epoch 6/40
# 500/500 - 2s - 4ms/step - accuracy: 0.7557 - loss: 0.6991 - val_accuracy: 0.7600 - val_loss: 0.6848
# Epoch 7/40
# 500/500 - 2s - 4ms/step - accuracy: 0.7746 - loss: 0.6453 - val_accuracy: 0.7770 - val_loss: 0.6413
# Epoch 8/40
# 500/500 - 2s - 4ms/step - accuracy: 0.7867 - loss: 0.6059 - val_accuracy: 0.7933 - val_loss: 0.6270
# Epoch 9/40
# 500/500 - 2s - 4ms/step - accuracy: 0.8006 - loss: 0.5693 - val_accuracy: 0.7891 - val_loss: 0.6188
# Epoch 10/40
# 500/500 - 2s - 4ms/step - accuracy: 0.8107 - loss: 0.5379 - val_accuracy: 0.7951 - val_loss: 0.6110
# Epoch 11/40
# 500/500 - 2s - 4ms/step - accuracy: 0.8195 - loss: 0.5098 - val_accuracy: 0.7974 - val_loss: 0.6049
# Epoch 12/40
# 500/500 - 2s - 4ms/step - accuracy: 0.8270 - loss: 0.4895 - val_accuracy: 0.8035 - val_loss: 0.5890
# Epoch 13/40
# 500/500 - 2s - 4ms/step - accuracy: 0.8389 - loss: 0.4570 - val_accuracy: 0.8012 - val_loss: 0.6009
# Epoch 14/40
# 500/500 - 2s - 4ms/step - accuracy: 0.8439 - loss: 0.4459 - val_accuracy: 0.7963 - val_loss: 0.6209
# Epoch 15/40
# 500/500 - 2s - 4ms/step - accuracy: 0.8491 - loss: 0.4219 - val_accuracy: 0.8026 - val_loss: 0.6080
# Epoch 16/40
# 500/500 - 2s - 4ms/step - accuracy: 0.8566 - loss: 0.4064 - val_accuracy: 0.8057 - val_loss: 0.5999
# Epoch 17/40
# 500/500 - 2s - 4ms/step - accuracy: 0.8582 - loss: 0.3940 - val_accuracy: 0.8041 - val_loss: 0.6145
# Epoch 18/40
# 500/500 - 2s - 4ms/step - accuracy: 0.8632 - loss: 0.3820 - val_accuracy: 0.8100 - val_loss: 0.5980
# Epoch 19/40
# 500/500 - 2s - 4ms/step - accuracy: 0.8711 - loss: 0.3646 - val_accuracy: 0.8014 - val_loss: 0.6212
# Epoch 20/40
# 500/500 - 2s - 4ms/step - accuracy: 0.8722 - loss: 0.3581 - val_accuracy: 0.8111 - val_loss: 0.5996
# Epoch 21/40
# 500/500 - 2s - 4ms/step - accuracy: 0.8767 - loss: 0.3481 - val_accuracy: 0.8076 - val_loss: 0.6244
# Epoch 22/40
# 500/500 - 2s - 4ms/step - accuracy: 0.8778 - loss: 0.3406 - val_accuracy: 0.8109 - val_loss: 0.6268
# Epoch 23/40
# 500/500 - 2s - 4ms/step - accuracy: 0.8824 - loss: 0.3269 - val_accuracy: 0.8102 - val_loss: 0.6251
# Epoch 24/40
# 500/500 - 2s - 4ms/step - accuracy: 0.8854 - loss: 0.3198 - val_accuracy: 0.8128 - val_loss: 0.6184
# Epoch 25/40
# 500/500 - 2s - 4ms/step - accuracy: 0.8876 - loss: 0.3111 - val_accuracy: 0.8136 - val_loss: 0.6151
# Epoch 26/40
# 500/500 - 2s - 4ms/step - accuracy: 0.8916 - loss: 0.3030 - val_accuracy: 0.8145 - val_loss: 0.6256
# Epoch 27/40
# 500/500 - 2s - 4ms/step - accuracy: 0.8940 - loss: 0.2994 - val_accuracy: 0.8114 - val_loss: 0.6548
# Epoch 28/40
# 500/500 - 2s - 4ms/step - accuracy: 0.8940 - loss: 0.2944 - val_accuracy: 0.8118 - val_loss: 0.6498
# Epoch 29/40
# 500/500 - 2s - 4ms/step - accuracy: 0.8935 - loss: 0.2933 - val_accuracy: 0.8111 - val_loss: 0.6363
# Epoch 30/40
# 500/500 - 2s - 4ms/step - accuracy: 0.8971 - loss: 0.2843 - val_accuracy: 0.8153 - val_loss: 0.6287
# Epoch 31/40
# 500/500 - 2s - 4ms/step - accuracy: 0.9002 - loss: 0.2794 - val_accuracy: 0.8173 - val_loss: 0.6423
# Epoch 32/40
# 500/500 - 2s - 4ms/step - accuracy: 0.8999 - loss: 0.2799 - val_accuracy: 0.8166 - val_loss: 0.6665
# Epoch 33/40
# 500/500 - 2s - 4ms/step - accuracy: 0.9054 - loss: 0.2665 - val_accuracy: 0.8109 - val_loss: 0.6717
# Epoch 34/40
# 500/500 - 2s - 4ms/step - accuracy: 0.9065 - loss: 0.2634 - val_accuracy: 0.8144 - val_loss: 0.6533
# Epoch 35/40
# 500/500 - 2s - 4ms/step - accuracy: 0.9082 - loss: 0.2550 - val_accuracy: 0.8106 - val_loss: 0.6681
# Epoch 36/40
# 500/500 - 2s - 4ms/step - accuracy: 0.9080 - loss: 0.2613 - val_accuracy: 0.8151 - val_loss: 0.6649
# Epoch 37/40
# 500/500 - 2s - 4ms/step - accuracy: 0.9119 - loss: 0.2489 - val_accuracy: 0.8103 - val_loss: 0.6898
# Epoch 38/40
# 500/500 - 2s - 4ms/step - accuracy: 0.9105 - loss: 0.2487 - val_accuracy: 0.8148 - val_loss: 0.6646
# Epoch 39/40
# 500/500 - 2s - 4ms/step - accuracy: 0.9121 - loss: 0.2474 - val_accuracy: 0.8161 - val_loss: 0.6712
# Epoch 40/40
# 500/500 - 2s - 4ms/step - accuracy: 0.9122 - loss: 0.2470 - val_accuracy: 0.8167 - val_loss: 0.6817
# Final accuracy on training set: 0.9122
# Final accuracy on test set: 0.8167
# Mean accuracy in last 5 epochs: 0.8146

# %% [markdown]
# ## Combined Parallel Branches and Skip Connections

# %%
def cnn_model_api(input_shape=(28,28,1), conv_units=(32,64,128,256)):
  inputs = Input(shape=input_shape)
  #parallel branches
  branch1 = Conv2D(32, kernel_size=(3, 3),activation='relu', padding='same')(inputs)
  branch1 = Conv2D(32, kernel_size=(3, 3),activation='relu', padding='same')(branch1)
  branch2 = Conv2D(32, kernel_size=(5, 5),activation='relu', padding='same')(inputs)
  branch3 = Conv2D(32, kernel_size=(1, 1),activation='relu', padding='same')(inputs)
  branch3 = Conv2D(32, kernel_size=(5, 5),activation='relu', padding='same')(branch3)
  concatanated = Concatenate()([branch1,branch2,branch3])
  net = MaxPooling2D(pool_size=(2, 2))(concatanated)
  net = Dropout(0.2)(net)
  #skip connection
  net = Conv2D(32, kernel_size=(3, 3),activation='relu', padding='same')(net)
  net = Conv2D(32, kernel_size=(3, 3),activation='relu', padding='same')(net)
  skip = MaxPooling2D(pool_size=(2, 2))(net)
  net = Conv2D(32, kernel_size=(3, 3),activation='relu', padding='same')(skip)
  net = Conv2D(32, kernel_size=(3, 3),activation='relu', padding='same')(net)
  added = Add()([net,skip])
  net = MaxPooling2D(pool_size=(2, 2))(added)
  net = Dropout(0.2)(net)
  net = Conv2D(128, kernel_size=(3, 3),activation='relu', padding='same')(net)
  net = Conv2D(128, kernel_size=(3, 3),activation='relu', padding='same')(net)
  net = MaxPooling2D(pool_size=(2, 2))(net)
  net = Dropout(0.2)(net)
  net = Flatten()(net)
  net = Dense(128, activation='relu')(net)
  net = Dropout(0.2)(net)
  outputs = Dense(10, activation='softmax')(net)
  model = Model(inputs=inputs, outputs=outputs, name='classification_model')
  return model

# %%
cnn = cnn_model_api(input_shape=x_train.shape[1:])
# plot_model(cnn, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
cnn.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss="categorical_crossentropy", metrics=["accuracy"])
history = cnn.fit(
    x_train, y_train,
    epochs =  40,
    batch_size=100,
    verbose = 2,
    validation_data=(x_test, y_test),
)

print('Final accuracy on training set: {:.4f}'.format(history.history['accuracy'][-1]))
print('Final accuracy on test set: {:.4f}'.format(history.history['val_accuracy'][-1]))
print('Mean accuracy in last 5 epochs: {:.4f}'.format(np.mean(history.history['val_accuracy'][-5:])))
# Out:
# Epoch 1/40
# 500/500 - 14s - 28ms/step - accuracy: 0.3417 - loss: 1.7547 - val_accuracy: 0.4758 - val_loss: 1.4026
# Epoch 2/40
# 500/500 - 3s - 6ms/step - accuracy: 0.5250 - loss: 1.3002 - val_accuracy: 0.5707 - val_loss: 1.1763
# Epoch 3/40
# 500/500 - 3s - 6ms/step - accuracy: 0.6072 - loss: 1.0976 - val_accuracy: 0.6454 - val_loss: 0.9750
# Epoch 4/40
# 500/500 - 3s - 6ms/step - accuracy: 0.6478 - loss: 0.9957 - val_accuracy: 0.6812 - val_loss: 0.8913
# Epoch 5/40
# 500/500 - 3s - 6ms/step - accuracy: 0.6771 - loss: 0.9186 - val_accuracy: 0.6950 - val_loss: 0.8759
# Epoch 6/40
# 500/500 - 3s - 6ms/step - accuracy: 0.6980 - loss: 0.8543 - val_accuracy: 0.7085 - val_loss: 0.8413
# Epoch 7/40
# 500/500 - 3s - 6ms/step - accuracy: 0.7170 - loss: 0.8045 - val_accuracy: 0.7269 - val_loss: 0.7823
# Epoch 8/40
# 500/500 - 3s - 6ms/step - accuracy: 0.7328 - loss: 0.7631 - val_accuracy: 0.7419 - val_loss: 0.7509
# Epoch 9/40
# 500/500 - 3s - 6ms/step - accuracy: 0.7477 - loss: 0.7126 - val_accuracy: 0.7381 - val_loss: 0.7604
# Epoch 10/40
# 500/500 - 3s - 6ms/step - accuracy: 0.7579 - loss: 0.6901 - val_accuracy: 0.7577 - val_loss: 0.7093
# Epoch 11/40
# 500/500 - 3s - 6ms/step - accuracy: 0.7676 - loss: 0.6591 - val_accuracy: 0.7596 - val_loss: 0.7108
# Epoch 12/40
# 500/500 - 3s - 6ms/step - accuracy: 0.7771 - loss: 0.6369 - val_accuracy: 0.7772 - val_loss: 0.6677
# Epoch 13/40
# 500/500 - 3s - 6ms/step - accuracy: 0.7847 - loss: 0.6083 - val_accuracy: 0.7655 - val_loss: 0.6899
# Epoch 14/40
# 500/500 - 3s - 6ms/step - accuracy: 0.7908 - loss: 0.5965 - val_accuracy: 0.7791 - val_loss: 0.6594
# Epoch 15/40
# 500/500 - 3s - 6ms/step - accuracy: 0.7997 - loss: 0.5699 - val_accuracy: 0.7825 - val_loss: 0.6450
# Epoch 16/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8051 - loss: 0.5560 - val_accuracy: 0.7808 - val_loss: 0.6534
# Epoch 17/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8094 - loss: 0.5411 - val_accuracy: 0.7810 - val_loss: 0.6718
# Epoch 18/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8125 - loss: 0.5295 - val_accuracy: 0.7890 - val_loss: 0.6346
# Epoch 19/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8176 - loss: 0.5184 - val_accuracy: 0.7878 - val_loss: 0.6520
# Epoch 20/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8211 - loss: 0.5055 - val_accuracy: 0.7863 - val_loss: 0.6511
# Epoch 21/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8269 - loss: 0.4879 - val_accuracy: 0.7754 - val_loss: 0.7122
# Epoch 22/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8271 - loss: 0.4827 - val_accuracy: 0.7951 - val_loss: 0.6412
# Epoch 23/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8324 - loss: 0.4709 - val_accuracy: 0.7900 - val_loss: 0.6556
# Epoch 24/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8373 - loss: 0.4642 - val_accuracy: 0.7937 - val_loss: 0.6387
# Epoch 25/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8363 - loss: 0.4590 - val_accuracy: 0.8026 - val_loss: 0.6322
# Epoch 26/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8420 - loss: 0.4467 - val_accuracy: 0.7960 - val_loss: 0.6569
# Epoch 27/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8440 - loss: 0.4384 - val_accuracy: 0.7998 - val_loss: 0.6204
# Epoch 28/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8445 - loss: 0.4375 - val_accuracy: 0.7953 - val_loss: 0.6416
# Epoch 29/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8463 - loss: 0.4285 - val_accuracy: 0.7965 - val_loss: 0.6444
# Epoch 30/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8505 - loss: 0.4216 - val_accuracy: 0.7996 - val_loss: 0.6487
# Epoch 31/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8524 - loss: 0.4182 - val_accuracy: 0.7957 - val_loss: 0.6505
# Epoch 32/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8540 - loss: 0.4110 - val_accuracy: 0.7967 - val_loss: 0.6656
# Epoch 33/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8553 - loss: 0.4110 - val_accuracy: 0.7997 - val_loss: 0.6483
# Epoch 34/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8594 - loss: 0.3966 - val_accuracy: 0.7988 - val_loss: 0.6592
# Epoch 35/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8572 - loss: 0.3946 - val_accuracy: 0.7943 - val_loss: 0.6730
# Epoch 36/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8594 - loss: 0.3925 - val_accuracy: 0.7915 - val_loss: 0.6800
# Epoch 37/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8646 - loss: 0.3853 - val_accuracy: 0.7983 - val_loss: 0.6703
# Epoch 38/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8644 - loss: 0.3856 - val_accuracy: 0.7980 - val_loss: 0.6287
# Epoch 39/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8668 - loss: 0.3730 - val_accuracy: 0.8022 - val_loss: 0.6614
# Epoch 40/40
# 500/500 - 3s - 6ms/step - accuracy: 0.8642 - loss: 0.3833 - val_accuracy: 0.8026 - val_loss: 0.6390
# Final accuracy on training set: 0.8642
# Final accuracy on test set: 0.8026
# Mean accuracy in last 5 epochs: 0.7985

# %% [markdown]
# ## Inception-Style CIFAR-10 Network

# %%
import tensorflow.keras.layers as layers

def inception_module(x, filters_1x1, filters_3x3, filters_5x5, filters_pool_proj):
    # 1x1 conv branch
    conv1x1 = layers.Conv2D(filters_1x1, (1, 1), padding='same', activation='relu')(x)

    # 3x3 conv branch
    conv3x3 = layers.Conv2D(filters_3x3, (3, 3), padding='same', activation='relu')(x)

    # 5x5 conv branch
    conv5x5 = layers.Conv2D(filters_5x5, (5, 5), padding='same', activation='relu')(x)

    # 3x3 max pooling branch
    pool_proj = layers.MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    pool_proj = layers.Conv2D(filters_pool_proj, (1, 1), padding='same', activation='relu')(pool_proj)

    # Concatenate filters
    output = layers.concatenate([conv1x1, conv3x3, conv5x5, pool_proj], axis=-1)
    return output

# %%
import tensorflow.keras.layers as layers
from tensorflow.keras import Model, Input

def inception_cifar10(input_shape=(32, 32, 3), num_classes=10):
    inputs = Input(shape=input_shape)

    # Initial conv layer
    x = layers.Conv2D(64, (3, 3), padding='same', activation='relu')(inputs)
    x = layers.MaxPooling2D((2, 2))(x)

    # Inception Block 1
    x = inception_module(x, 32, 32, 32, 32)
    x = layers.MaxPooling2D((2, 2))(x)

    # Inception Block 2
    x = inception_module(x, 64, 64, 64, 64)
    x = layers.MaxPooling2D((2, 2))(x)

    # Inception Block 3
    x = inception_module(x, 128, 128, 128, 128)

    # Classification Head
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs, name="Inception_CIFAR10")
    return model

# %%
model = inception_cifar10()
model.summary()
# Out:
# Model: "Inception_CIFAR10"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_16      │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_103 (Conv2D) │ (None, 32, 32,    │      1,792 │ input_layer_16[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_40    │ (None, 16, 16,    │          0 │ conv2d_103[0][0]  │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_41    │ (None, 16, 16,    │          0 │ max_pooling2d_40… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_104 (Conv2D) │ (None, 16, 16,    │      2,080 │ max_pooling2d_40… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_105 (Conv2D) │ (None, 16, 16,    │     18,464 │ max_pooling2d_40… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_106 (Conv2D) │ (None, 16, 16,    │     51,232 │ max_pooling2d_40… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_107 (Conv2D) │ (None, 16, 16,    │      2,080 │ max_pooling2d_41… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 16, 16,    │          0 │ conv2d_104[0][0], │
# │ (Concatenate)       │ 128)              │            │ conv2d_105[0][0], │
# │                     │                   │            │ conv2d_106[0][0], │
# │                     │                   │            │ conv2d_107[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_42    │ (None, 8, 8, 128) │          0 │ concatenate_7[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_43    │ (None, 8, 8, 128) │          0 │ max_pooling2d_42… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_108 (Conv2D) │ (None, 8, 8, 64)  │      8,256 │ max_pooling2d_42… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_109 (Conv2D) │ (None, 8, 8, 64)  │     73,792 │ max_pooling2d_42… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_110 (Conv2D) │ (None, 8, 8, 64)  │    204,864 │ max_pooling2d_42… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_111 (Conv2D) │ (None, 8, 8, 64)  │      8,256 │ max_pooling2d_43… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 8, 8, 256) │          0 │ conv2d_108[0][0], │
# │ (Concatenate)       │                   │            │ conv2d_109[0][0], │
# │                     │                   │            │ conv2d_110[0][0], │
# │                     │                   │            │ conv2d_111[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_44    │ (None, 4, 4, 256) │          0 │ concatenate_8[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_45    │ (None, 4, 4, 256) │          0 │ max_pooling2d_44… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_112 (Conv2D) │ (None, 4, 4, 128) │     32,896 │ max_pooling2d_44… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_113 (Conv2D) │ (None, 4, 4, 128) │    295,040 │ max_pooling2d_44… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_114 (Conv2D) │ (None, 4, 4, 128) │    819,328 │ max_pooling2d_44… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_115 (Conv2D) │ (None, 4, 4, 128) │     32,896 │ max_pooling2d_45… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 4, 4, 512) │          0 │ conv2d_112[0][0], │
# │ (Concatenate)       │                   │            │ conv2d_113[0][0], │
# │                     │                   │            │ conv2d_114[0][0], │
# │                     │                   │            │ conv2d_115[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ concatenate_9[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_47          │ (None, 512)       │          0 │ global_average_p… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_24 (Dense)    │ (None, 10)        │      5,130 │ dropout_47[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,556,106 (5.94 MB)
#  Trainable params: 1,556,106 (5.94 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
history = model.fit(
    x_train, y_train,
    epochs =  10,
    batch_size=256,
    verbose = 1,
    validation_data=(x_test, y_test),
)

print('Final accuracy on training set: {:.4f}'.format(history.history['accuracy'][-1]))
print('Final accuracy on test set: {:.4f}'.format(history.history['val_accuracy'][-1]))
print('Mean accuracy in last 5 epochs: {:.4f}'.format(np.mean(history.history['val_accuracy'][-5:])))
# Out:
# Epoch 1/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 64s 148ms/step - accuracy: 0.7708 - loss: 0.6542 - val_accuracy: 0.7143 - val_loss: 0.8649
# Epoch 2/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.7969 - loss: 0.5804 - val_accuracy: 0.6808 - val_loss: 1.0112
# Epoch 3/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.8155 - loss: 0.5250 - val_accuracy: 0.7150 - val_loss: 0.9200
# Epoch 4/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 10s 53ms/step - accuracy: 0.8267 - loss: 0.4911 - val_accuracy: 0.7254 - val_loss: 0.8386
# Epoch 5/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.8437 - loss: 0.4455 - val_accuracy: 0.7350 - val_loss: 0.8144
# Epoch 6/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.8571 - loss: 0.4103 - val_accuracy: 0.7259 - val_loss: 0.8922
# Epoch 7/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.8678 - loss: 0.3741 - val_accuracy: 0.6968 - val_loss: 0.9759
# Epoch 8/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.8776 - loss: 0.3451 - val_accuracy: 0.7379 - val_loss: 0.8611
# Epoch 9/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.8890 - loss: 0.3162 - val_accuracy: 0.7093 - val_loss: 1.0415
# Epoch 10/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - accuracy: 0.8989 - loss: 0.2870 - val_accuracy: 0.6973 - val_loss: 1.1260
# Final accuracy on training set: 0.8989
# Final accuracy on test set: 0.6973
# Mean accuracy in last 5 epochs: 0.7134

# %% [markdown]
# ## Residual Network

# %%
def residual_block(x, filters, downsample=False):
    """
    Residual block with optional downsampling.
    If downsample=True, reduces spatial dimension by stride=2.
    """
    shortcut = x

    stride = 2 if downsample else 1

    # First conv layer
    x = layers.Conv2D(filters, (3, 3), strides=stride, padding='same',
                      use_bias=False, activation=None)(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    # Second conv layer
    x = layers.Conv2D(filters, (3, 3), padding='same',
                      use_bias=False, activation=None)(x)
    x = layers.BatchNormalization()(x)

    # Adjust shortcut if dimensions differ (for downsampling or channel mismatch)
    if downsample or shortcut.shape[-1] != filters:
        shortcut = layers.Conv2D(filters, (1, 1), strides=stride,
                                 padding='same', use_bias=False)(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)

    # Add skip connection
    x = layers.Add()([x, shortcut])
    x = layers.ReLU()(x)

    return x

# %%
def resnet_cifar10(input_shape=(32, 32, 3), num_classes=10):
    inputs = Input(shape=input_shape)

    # Initial convolution
    x = layers.Conv2D(32, (3, 3), padding='same', use_bias=False)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    # Residual blocks
    x = residual_block(x, 32)
    x = residual_block(x, 32)

    x = residual_block(x, 64, downsample=True)
    x = residual_block(x, 64)

    x = residual_block(x, 128, downsample=True)
    x = residual_block(x, 128)

    # Global average pooling and classifier
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs, name='ResNet_CIFAR10')
    return model

# %%
model = resnet_cifar10()
model.summary()
# Out:
# Model: "ResNet_CIFAR10"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_25      │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_252 (Conv2D) │ (None, 32, 32,    │        864 │ input_layer_25[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ conv2d_252[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_52 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_253 (Conv2D) │ (None, 32, 32,    │      9,216 │ re_lu_52[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ conv2d_253[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_53 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_254 (Conv2D) │ (None, 32, 32,    │      9,216 │ re_lu_53[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ conv2d_254[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_41 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ re_lu_52[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_54 (ReLU)     │ (None, 32, 32,    │          0 │ add_41[0][0]      │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_255 (Conv2D) │ (None, 32, 32,    │      9,216 │ re_lu_54[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ conv2d_255[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_55 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_256 (Conv2D) │ (None, 32, 32,    │      9,216 │ re_lu_55[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ conv2d_256[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_42 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ re_lu_54[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_56 (ReLU)     │ (None, 32, 32,    │          0 │ add_42[0][0]      │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_257 (Conv2D) │ (None, 16, 16,    │     18,432 │ re_lu_56[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_257[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_57 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_258 (Conv2D) │ (None, 16, 16,    │     36,864 │ re_lu_57[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_259 (Conv2D) │ (None, 16, 16,    │      2,048 │ re_lu_56[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_258[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_259[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_43 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_58 (ReLU)     │ (None, 16, 16,    │          0 │ add_43[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_260 (Conv2D) │ (None, 16, 16,    │     36,864 │ re_lu_58[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_260[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_59 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_261 (Conv2D) │ (None, 16, 16,    │     36,864 │ re_lu_59[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_261[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_44 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ re_lu_58[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_60 (ReLU)     │ (None, 16, 16,    │          0 │ add_44[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_262 (Conv2D) │ (None, 8, 8, 128) │     73,728 │ re_lu_60[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 128) │        512 │ conv2d_262[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_61 (ReLU)     │ (None, 8, 8, 128) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_263 (Conv2D) │ (None, 8, 8, 128) │    147,456 │ re_lu_61[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_264 (Conv2D) │ (None, 8, 8, 128) │      8,192 │ re_lu_60[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 128) │        512 │ conv2d_263[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 128) │        512 │ conv2d_264[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_45 (Add)        │ (None, 8, 8, 128) │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_62 (ReLU)     │ (None, 8, 8, 128) │          0 │ add_45[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_265 (Conv2D) │ (None, 8, 8, 128) │    147,456 │ re_lu_62[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 128) │        512 │ conv2d_265[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_63 (ReLU)     │ (None, 8, 8, 128) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_266 (Conv2D) │ (None, 8, 8, 128) │    147,456 │ re_lu_63[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 128) │        512 │ conv2d_266[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_46 (Add)        │ (None, 8, 8, 128) │          0 │ batch_normalizat… │
# │                     │                   │            │ re_lu_62[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_64 (ReLU)     │ (None, 8, 8, 128) │          0 │ add_46[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ re_lu_64[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_65          │ (None, 128)       │          0 │ global_average_p… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_37 (Dense)    │ (None, 10)        │      1,290 │ dropout_65[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 698,858 (2.67 MB)
#  Trainable params: 696,618 (2.66 MB)
#  Non-trainable params: 2,240 (8.75 KB)

# %%
#plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
history = model.fit(
    x_train, y_train,
    epochs =  10,
    batch_size=256,
    verbose = 1,
    validation_data=(x_test, y_test),
)

print('Final accuracy on training set: {:.4f}'.format(history.history['accuracy'][-1]))
print('Final accuracy on test set: {:.4f}'.format(history.history['val_accuracy'][-1]))
print('Mean accuracy in last 5 epochs: {:.4f}'.format(np.mean(history.history['val_accuracy'][-5:])))
# Out:
# Epoch 1/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 22s 55ms/step - accuracy: 0.4280 - loss: 1.6016 - val_accuracy: 0.1487 - val_loss: 3.6111
# Epoch 2/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.6192 - loss: 1.0756 - val_accuracy: 0.4831 - val_loss: 1.5197
# Epoch 3/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.6995 - loss: 0.8594 - val_accuracy: 0.6652 - val_loss: 0.9324
# Epoch 4/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7505 - loss: 0.7252 - val_accuracy: 0.6479 - val_loss: 1.0541
# Epoch 5/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7868 - loss: 0.6232 - val_accuracy: 0.5860 - val_loss: 1.3819
# Epoch 6/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8153 - loss: 0.5422 - val_accuracy: 0.6767 - val_loss: 0.9672
# Epoch 7/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8419 - loss: 0.4661 - val_accuracy: 0.6871 - val_loss: 1.0068
# Epoch 8/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8613 - loss: 0.4093 - val_accuracy: 0.7226 - val_loss: 0.8856
# Epoch 9/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8779 - loss: 0.3569 - val_accuracy: 0.6176 - val_loss: 1.3549
# Epoch 10/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8951 - loss: 0.3141 - val_accuracy: 0.5469 - val_loss: 1.9890
# Final accuracy on training set: 0.8951
# Final accuracy on test set: 0.5469
# Mean accuracy in last 5 epochs: 0.6502

# %% [markdown]
# ## Residual Network with Parallel Branches

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, ReLU, Add, GlobalAveragePooling2D, Dense, Concatenate

from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

def convolutional_block(X, filters, kernel_size=(3, 3), strides=(1, 1), padding='same'):
    F1, F2 = filters

    X_shortcut = X

    X = Conv2D(F1, kernel_size, strides=strides, padding=padding)(X)
    X = BatchNormalization()(X)
    X = ReLU()(X)

    X = Conv2D(F2, kernel_size, strides=(1, 1), padding=padding)(X)
    X = BatchNormalization()(X)

    # Shortcut path
    X_shortcut = Conv2D(F2, kernel_size=(1, 1), strides=strides, padding=padding)(X_shortcut)
    X_shortcut = BatchNormalization()(X_shortcut)

    X = Add()([X, X_shortcut])

    return X

def parallel_branch(X, filters, kernel_size=(3, 3), strides=(1, 1), padding='same'):
    X1 = convolutional_block(X, filters, kernel_size, strides, padding)
    X2 = convolutional_block(X1, filters, kernel_size, strides, padding)
    X3 = convolutional_block(X2, filters, kernel_size, strides, padding)

    return [X1, X2, X3]

def ResNetParallelBranches(input_shape=(32, 32, 3), classes=10):
    X_input = Input(input_shape)

    X = Conv2D(64, (7, 7), strides=(2, 2), padding='same')(X_input)
    X = BatchNormalization()(X)
    X = ReLU()(X)

    # Parallel branches
    branches = parallel_branch(X, filters=[64, 64])
    X = Concatenate()(branches)

    X = parallel_branch(X, filters=[64, 64])
    X = Concatenate()(X)

    X = parallel_branch(X, filters=[128, 128])
    X = Concatenate()(X)

    X = parallel_branch(X, filters=[256, 256])
    X = Concatenate()(X)

    X = GlobalAveragePooling2D()(X)

    X = Dense(classes, activation='softmax')(X)

    model = tf.keras.models.Model(inputs=X_input, outputs=X)

    return model


model = ResNetParallelBranches(input_shape=(32, 32, 3), classes=10)
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_26      │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_267 (Conv2D) │ (None, 16, 16,    │      9,472 │ input_layer_26[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_267[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_65 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_268 (Conv2D) │ (None, 16, 16,    │     36,928 │ re_lu_65[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_268[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_66 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_269 (Conv2D) │ (None, 16, 16,    │     36,928 │ re_lu_66[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_270 (Conv2D) │ (None, 16, 16,    │      4,160 │ re_lu_65[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_269[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_270[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_47 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_271 (Conv2D) │ (None, 16, 16,    │     36,928 │ add_47[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_271[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_67 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_272 (Conv2D) │ (None, 16, 16,    │     36,928 │ re_lu_67[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_273 (Conv2D) │ (None, 16, 16,    │      4,160 │ add_47[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_272[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_273[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_48 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_274 (Conv2D) │ (None, 16, 16,    │     36,928 │ add_48[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_274[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_68 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_275 (Conv2D) │ (None, 16, 16,    │     36,928 │ re_lu_68[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_276 (Conv2D) │ (None, 16, 16,    │      4,160 │ add_48[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_275[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_276[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_49 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_20      │ (None, 16, 16,    │          0 │ add_47[0][0],     │
# │ (Concatenate)       │ 192)              │            │ add_48[0][0],     │
# │                     │                   │            │ add_49[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_277 (Conv2D) │ (None, 16, 16,    │    110,656 │ concatenate_20[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_277[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_69 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_278 (Conv2D) │ (None, 16, 16,    │     36,928 │ re_lu_69[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_279 (Conv2D) │ (None, 16, 16,    │     12,352 │ concatenate_20[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_278[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_279[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_50 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_280 (Conv2D) │ (None, 16, 16,    │     36,928 │ add_50[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_280[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_70 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_281 (Conv2D) │ (None, 16, 16,    │     36,928 │ re_lu_70[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_282 (Conv2D) │ (None, 16, 16,    │      4,160 │ add_50[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_281[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_282[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_51 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_283 (Conv2D) │ (None, 16, 16,    │     36,928 │ add_51[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_283[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_71 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_284 (Conv2D) │ (None, 16, 16,    │     36,928 │ re_lu_71[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_285 (Conv2D) │ (None, 16, 16,    │      4,160 │ add_51[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_284[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_285[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_52 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_21      │ (None, 16, 16,    │          0 │ add_50[0][0],     │
# │ (Concatenate)       │ 192)              │            │ add_51[0][0],     │
# │                     │                   │            │ add_52[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_286 (Conv2D) │ (None, 16, 16,    │    221,312 │ concatenate_21[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_286[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_72 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_287 (Conv2D) │ (None, 16, 16,    │    147,584 │ re_lu_72[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_288 (Conv2D) │ (None, 16, 16,    │     24,704 │ concatenate_21[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_287[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_288[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_53 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_289 (Conv2D) │ (None, 16, 16,    │    147,584 │ add_53[0][0]      │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_289[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_73 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_290 (Conv2D) │ (None, 16, 16,    │    147,584 │ re_lu_73[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_291 (Conv2D) │ (None, 16, 16,    │     16,512 │ add_53[0][0]      │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_290[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_291[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_54 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_292 (Conv2D) │ (None, 16, 16,    │    147,584 │ add_54[0][0]      │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_292[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_74 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_293 (Conv2D) │ (None, 16, 16,    │    147,584 │ re_lu_74[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_294 (Conv2D) │ (None, 16, 16,    │     16,512 │ add_54[0][0]      │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_293[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_294[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_55 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_22      │ (None, 16, 16,    │          0 │ add_53[0][0],     │
# │ (Concatenate)       │ 384)              │            │ add_54[0][0],     │
# │                     │                   │            │ add_55[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_295 (Conv2D) │ (None, 16, 16,    │    884,992 │ concatenate_22[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_295[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_75 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_296 (Conv2D) │ (None, 16, 16,    │    590,080 │ re_lu_75[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_297 (Conv2D) │ (None, 16, 16,    │     98,560 │ concatenate_22[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_296[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_297[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_56 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_298 (Conv2D) │ (None, 16, 16,    │    590,080 │ add_56[0][0]      │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_298[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_76 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_299 (Conv2D) │ (None, 16, 16,    │    590,080 │ re_lu_76[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_300 (Conv2D) │ (None, 16, 16,    │     65,792 │ add_56[0][0]      │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_299[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_300[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_57 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_301 (Conv2D) │ (None, 16, 16,    │    590,080 │ add_57[0][0]      │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_301[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_77 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_302 (Conv2D) │ (None, 16, 16,    │    590,080 │ re_lu_77[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_303 (Conv2D) │ (None, 16, 16,    │     65,792 │ add_57[0][0]      │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_302[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_303[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_58 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_23      │ (None, 16, 16,    │          0 │ add_56[0][0],     │
# │ (Concatenate)       │ 768)              │            │ add_57[0][0],     │
# │                     │                   │            │ add_58[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 768)       │          0 │ concatenate_23[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_38 (Dense)    │ (None, 10)        │      7,690 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,668,362 (21.62 MB)
#  Trainable params: 5,659,018 (21.59 MB)
#  Non-trainable params: 9,344 (36.50 KB)

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train / 255.0
x_test = x_test / 255.0
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)


model = ResNetParallelBranches(input_shape=(32, 32, 3), classes=10)


model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])



early_stopping = EarlyStopping(monitor='val_loss',
                               patience=5,
                               mode='min',
                               verbose=1,
                               restore_best_weights=True)

history = model.fit(x_train, y_train,
                    epochs=30,
                    batch_size=64,
                    validation_split=0.2,
                    callbacks=[early_stopping])


test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}')
# Out:
# Epoch 1/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 46s 28ms/step - accuracy: 0.4123 - loss: 1.6078 - val_accuracy: 0.2966 - val_loss: 2.3662
# Epoch 2/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.5511 - loss: 1.2454 - val_accuracy: 0.3324 - val_loss: 2.7062
# Epoch 3/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.6158 - loss: 1.0752 - val_accuracy: 0.3373 - val_loss: 3.6611
# Epoch 4/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.6589 - loss: 0.9579 - val_accuracy: 0.5961 - val_loss: 1.1727
# Epoch 5/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.7029 - loss: 0.8412 - val_accuracy: 0.4863 - val_loss: 1.8002
# Epoch 6/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.7337 - loss: 0.7659 - val_accuracy: 0.5169 - val_loss: 1.5342
# Epoch 7/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.7566 - loss: 0.6974 - val_accuracy: 0.7115 - val_loss: 0.8167
# Epoch 8/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.7768 - loss: 0.6397 - val_accuracy: 0.6549 - val_loss: 1.0779
# Epoch 9/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.7961 - loss: 0.5867 - val_accuracy: 0.6632 - val_loss: 1.0524
# Epoch 10/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 22ms/step - accuracy: 0.8106 - loss: 0.5444 - val_accuracy: 0.6334 - val_loss: 1.2159
# Epoch 11/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.8257 - loss: 0.5019 - val_accuracy: 0.7024 - val_loss: 0.9275
# Epoch 12/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - accuracy: 0.8335 - loss: 0.4705 - val_accuracy: 0.7015 - val_loss: 0.9846
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 7.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7069 - loss: 0.8442
# Test Loss: 0.8442, Test Accuracy: 0.7069

# %% [markdown]
# ## Alternate Functional CIFAR-10 Baseline

# %%
def cnn_model_api(input_shape=(28,28,1)):
  inputs = Input(shape=input_shape)
  net = Conv2D(32, kernel_size=(3, 3),activation='relu', padding='same')(inputs)
  net = Conv2D(32, kernel_size=(3, 3),activation='relu', padding='same')(net)
  net = MaxPooling2D(pool_size=(2, 2))(net)
  net = BatchNormalization()(net)
  net = Dropout(0.2)(net)
  net = Conv2D(64, kernel_size=(3, 3),activation='relu', padding='same')(net)
  net = Conv2D(64, kernel_size=(3, 3),activation='relu', padding='same')(net)
  net = MaxPooling2D(pool_size=(2, 2))(net)
  net = BatchNormalization()(net)
  net = Dropout(0.2)(net)
  net = Conv2D(128, kernel_size=(3, 3),activation='relu', padding='same')(net)
  net = Conv2D(128, kernel_size=(3, 3),activation='relu', padding='same')(net)
  net = MaxPooling2D(pool_size=(2, 2))(net)
  net = BatchNormalization()(net)
  net = Dropout(0.2)(net)
  net = Flatten()(net)
  net = Dense(128, activation='relu')(net)
  net = Dropout(0.2)(net)
  outputs = Dense(10, activation='softmax')(net)
  model = Model(inputs=inputs, outputs=outputs, name='classification_model')
  return model

# %%
cnn = cnn_model_api(input_shape=x_train.shape[1:])
cnn.summary()
# Out:
# Model: "classification_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_28 (InputLayer)     │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_341 (Conv2D)             │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_342 (Conv2D)             │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_59 (MaxPooling2D) │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_228         │ (None, 16, 16, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_66 (Dropout)            │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_343 (Conv2D)             │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_344 (Conv2D)             │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_60 (MaxPooling2D) │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_229         │ (None, 8, 8, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_67 (Dropout)            │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_345 (Conv2D)             │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_346 (Conv2D)             │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_61 (MaxPooling2D) │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_230         │ (None, 4, 4, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_68 (Dropout)            │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_16 (Flatten)            │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_40 (Dense)                │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_69 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_41 (Dense)                │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 551,466 (2.10 MB)
#  Trainable params: 551,018 (2.10 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
plot_model(cnn, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
cnn.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss="categorical_crossentropy", metrics=["accuracy"])
history = cnn.fit(
    x_train, y_train,
    epochs =  10,
    batch_size=100,
    verbose = 2,
    validation_data=(x_test, y_test),
)

print('Final accuracy on training set: {:.4f}'.format(history.history['accuracy'][-1]))
print('Final accuracy on test set: {:.4f}'.format(history.history['val_accuracy'][-1]))
print('Mean accuracy in last 5 epochs: {:.4f}'.format(np.mean(history.history['val_accuracy'][-5:])))
# Out:
# Epoch 1/10
# 500/500 - 12s - 23ms/step - accuracy: 0.4790 - loss: 1.4548 - val_accuracy: 0.3009 - val_loss: 2.9572
# Epoch 2/10
# 500/500 - 2s - 5ms/step - accuracy: 0.6433 - loss: 1.0092 - val_accuracy: 0.6747 - val_loss: 0.9340
# Epoch 3/10
# 500/500 - 2s - 5ms/step - accuracy: 0.7094 - loss: 0.8258 - val_accuracy: 0.7164 - val_loss: 0.8119
# Epoch 4/10
# 500/500 - 2s - 5ms/step - accuracy: 0.7476 - loss: 0.7162 - val_accuracy: 0.7204 - val_loss: 0.8214
# Epoch 5/10
# 500/500 - 2s - 5ms/step - accuracy: 0.7790 - loss: 0.6354 - val_accuracy: 0.7484 - val_loss: 0.7269
# Epoch 6/10
# 500/500 - 2s - 5ms/step - accuracy: 0.8008 - loss: 0.5754 - val_accuracy: 0.7680 - val_loss: 0.6905
# Epoch 7/10
# 500/500 - 2s - 5ms/step - accuracy: 0.8163 - loss: 0.5240 - val_accuracy: 0.7849 - val_loss: 0.6595
# Epoch 8/10
# 500/500 - 2s - 5ms/step - accuracy: 0.8292 - loss: 0.4848 - val_accuracy: 0.7342 - val_loss: 0.8615
# Epoch 9/10
# 500/500 - 2s - 5ms/step - accuracy: 0.8433 - loss: 0.4479 - val_accuracy: 0.7709 - val_loss: 0.6954
# Epoch 10/10
# 500/500 - 2s - 5ms/step - accuracy: 0.8528 - loss: 0.4199 - val_accuracy: 0.7586 - val_loss: 0.7603
# Final accuracy on training set: 0.8528
# Final accuracy on test set: 0.7586
# Mean accuracy in last 5 epochs: 0.7633

# %% [markdown]
# ## Architecture Progression
#
# The experiments progress from a conventional Functional API CNN to increasingly flexible computation graphs. Parallel feature extraction, residual shortcuts, and Inception-style branch fusion illustrate core ideas used in many modern vision architectures.
